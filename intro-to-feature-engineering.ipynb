# %% [markdown]
# # Feature engineering is the process of using domain knowledge to extract features from raw data. These features can be used to improve the performance of Machnine Learning Algorithms.

# %% [markdown]
# # 1. Feature Transformation

# %% [markdown]
# 1.1 Missing values inputation

# %% [markdown]
# 1.2 Handling Categorical Values

# %% [markdown]
# 1.3 Outlier Detection

# %% [markdown]
# 1.4 Feature Scaling

# %% [markdown]
# 2. Feature Construction

# %% [markdown]
# 3. Feature Selection

# %% [markdown]
# 4. Feature Extraction
